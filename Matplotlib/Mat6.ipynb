# %%
#Standard Normal Distribution
#X=X(normal Distribution)*sigma+mu
import numpy as np
import matplotlib.pyplot as plt



Xsn=np.random.randn(100)
sigma=5
u=60
X=Xsn*sigma+u

plt.hist(X)
# Out:
# (array([ 3.,  2.,  8., 10., 18., 21., 15., 13.,  6.,  4.]),
#  array([46.22649712, 48.74482696, 51.2631568 , 53.78148664, 56.29981647,
#         58.81814631, 61.33647615, 63.85480599, 66.37313583, 68.89146567,
#         71.40979551]),
#  <BarContainer object of 10 artists>)
