# %%
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("mnist_train.csv")
df.shape
# Out:
# (42000, 785)

# %%
data=df.values
X=data[:,1:]
Y=data[:,0]

def drawImg(X,Y,i):
    plt.imshow(X[i].reshape(28,28),cmap="gray")
    plt.show()
drawImg(X,Y,0)

# %%
split=int(0.80*X.shape[0])
X_train,Y_train=X[:split,:],Y[:split]
X_test,Y_test=X[split:,:],Y[split:]


plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.imshow(X_train[i].reshape(28,28),cmap='gray')
    plt.show()

# %%
from sklearn.model_selection import train_test_split
XT,Xt,YT,Yt=train_test_split(X,Y,test_size=0.2) #test_size will be 20 % of total  mean 80% goes to training

# %%
#Try to plot a visulization (Grid of first 25 images 5*5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       3 for i in range(25):
#       4     plt.subplot(5,5,i+1)
# ----> 5     plt.imshow(X_train[i].reshape(28,28),cmap='gray')
#       6     plt.show()
#
# NameError: name 'X_train' is not defined
